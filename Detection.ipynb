# %%
# %cd yolo
# Out:
# /workspace/Dual_kalman/yolo

# %% [markdown]
# # Detect YOLO_MAP_Print

# %%
# n
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/nmodel/best.pt --name YOLO_n_result --save-conf --view-img  --save-txt --device 0,1,2,3
# Out:
# python: can't open file 'detect_YOLO.py': [Errno 2] No such file or directory

# %%
# s
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/smodel/best.pt --name YOLO_s_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_YOLO: weights=['./weights_ex/smodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.020s)
# ...

# %%
# m
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/mmodel/best.pt --name YOLO_m_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_YOLO: weights=['./weights_ex/mmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.022s)
# ...

# %%
# l
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/lmodel/best.pt --name YOLO_l_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_YOLO: weights=['./weights_ex/lmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.033s)
# ...

# %%
# xl
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/xlmodel/best.pt --name  YOLO_xl_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_YOLO: weights=['./weights_ex/xlmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.033s)
# ...

# %%
li = [1,2,3,4] 
print(li[0:2])
# Out:
# [1, 2]

# %% [markdown]
# # Detect Kalman-YOLO

# %%
# n
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/nmodel/best.pt --name Kalman_n_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# dual_kalman: weights=['./weights_ex/nmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_n_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Traceback (most recent call last):
#   File "dual_kalman.py", line 354, in <module>
#     main(opt)
#   File "dual_kalman.py", line 349, in main
#     run(**vars(opt))
# ...

# %%
# s
# !python detect_adakalman3.py --source frame.mp4 --weight ./weights_ex/smodel/best.pt --name Kalman_s_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_adakalman3: weights=['./weights_ex/smodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# use_kalman2
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.021s)
# use_kalman2
# ...

# %%
# m
# !python detect_adakalman3.py --source frame.mp4 --weight ./weights_ex/mmodel/best.pt --name Kalman_m_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_adakalman3: weights=['./weights_ex/mmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# use_kalman2
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.025s)
# use_kalman2
# ...

# %%
# l
# !python detect_adakalman3.py --source frame.mp4 --weight ./weights_ex/lmodel/best.pt --name Kalman_l_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_adakalman3: weights=['./weights_ex/lmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# use_kalman2
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.030s)
# use_kalman2
# ...

# %%
# xl
# !python detect_adakalman3.py --source frame.mp4 --weight ./weights_ex/xlmodel/best.pt --name Kalman_xl_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect_adakalman3: weights=['./weights_ex/xlmodel/best.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# use_kalman2
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.038s)
# use_kalman2
# ...

# %% [markdown]
# # Detect YOLO_FPS_Print

# %%
# n
# !python detect-Copy1.py --source frame.mp4 --weight ./weights_ex/nmodel/best.pt --name FPS_n_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# python: can't open file 'detect-Copy1.py': [Errno 2] No such file or directory

# %%
# s
# !python detect-Copy1.py --source frame.mp4 --weight ./weights_ex/smodel/best.pt --name FPS_s_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect-Copy1: weights=['./weights_ex/smodel/best.pt'], source=frame.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.018s)
# ...

# %%
# m
# !python detect-Copy1.py --source frame.mp4 --weight ./weights_ex/mmodel/best.pt --name FPS_m_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect-Copy1: weights=['./weights_ex/mmodel/best.pt'], source=frame.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.023s)
# ...

# %%
# l
# !python detect-Copy1.py --source frame.mp4 --weight ./weights_ex/lmodel/best.pt --name FPS_l_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect-Copy1: weights=['./weights_ex/lmodel/best.pt'], source=frame.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.031s)
# ...

# %%
# xl
# !python detect-Copy1.py --source frame.mp4 --weight ./weights_ex/xlmodel/best.pt --name FPS_xl_result --save-conf  --save-txt --device 0,1,2,3
# Out:
# detect-Copy1: weights=['./weights_ex/xlmodel/best.pt'], source=frame.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 a153479 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/yolov5/frame.mp4: 384x640 1 drone, Done. (0.034s)
# ...
