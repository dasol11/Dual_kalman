# %%
pwd
# Out:
# '/workspace/Dual_kalman/yolo'

# %%
cd yolo

# %% [markdown]
# # Detect YOLO_MAP_Print

# %%
# n
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/nmodel/best_n_5.pt --name YOLO_n_result --save-conf  --save-txt --device 1,2,3 --conf-thres 0.35
# Out:
# detect_YOLO: weights=['./weights_ex/nmodel/best_n_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_n_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients, 4.2 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.017s)
# video 1/1 (2/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.011s)
# ...

# %%
# s
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/smodel/best_s_5.pt --name YOLO_s_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_YOLO: weights=['./weights_ex/smodel/best_s_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.019s)
# ...

# %%
# m
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/mmodel/best_m_5.pt --name YOLO_m_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_YOLO: weights=['./weights_ex/mmodel/best_m_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.025s)
# ...

# %%
# l
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/lmodel/best_l_5.pt --name YOLO_l_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_YOLO: weights=['./weights_ex/lmodel/best_l_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.030s)
# ...

# %%
# xl
# !python detect_YOLO.py --source frame.mp4 --weight ./weights_ex/xlmodel/best_xl_5.pt --name  YOLO_xl_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_YOLO: weights=['./weights_ex/xlmodel/best_xl_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=YOLO_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.037s)
# ...

# %% [markdown]
# # Detect YOLO_FPS_Print

# %%
# n
# !python detect.py --source frame.mp4 --weight ./weights_ex/nmodel/best_n_5.pt --name FPS_n_result --save-conf  --save-txt --device 0,1,2,3  --conf-thres 0.35
# Out:
# detect: weights=['./weights_ex/nmodel/best_n_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_n_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients, 4.2 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.017s)
# ...

# %%
# s
# !python detect.py --source frame.mp4 --weight ./weights_ex/smodel/best_s_4.pt --name FPS_s_result --save-conf  --save-txt --device 0,1,2,3   --conf-thres 0.35
# Out:
# detect: weights=['./weights_ex/smodel/best_s_4.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.018s)
# ...

# %%
# m
# !python detect.py --source frame.mp4 --weight ./weights_ex/mmodel/best_m_5.pt --name FPS_m_result --save-conf  --save-txt --device 0,1,2,3   --conf-thres 0.35
# Out:
# detect: weights=['./weights_ex/mmodel/best_m_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.028s)
# ...

# %%
# l
# !python detect.py --source frame.mp4 --weight ./weights_ex/lmodel/best_l_5.pt --name FPS_l_result --save-conf  --save-txt --device 0,1,2,3   --conf-thres 0.35
# Out:
# detect: weights=['./weights_ex/lmodel/best_l_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.031s)
# ...

# %%
# xl
# !python detect.py --source frame.mp4 --weight ./weights_ex/xlmodel/best_xl_5.pt --name FPS_xl_result --save-conf  --save-txt --device 0,1,2,3  --conf-thres 0.35
# Out:
# detect: weights=['./weights_ex/xlmodel/best_xl_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=FPS_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/yolo_kalman_v1/yolo/frame.mp4: 384x640 1 drone, Done. (0.031s)
# ...

# %% [markdown]
# # Detect Dual Kalman

# %%
# n
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/nmodel/best_n_5.pt --name Kalman_n_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# dual_kalman: weights=['./weights_ex/nmodel/best_n_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_n_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients, 4.2 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.022s)
# ...

# %%
# s
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/smodel/best_s_5.pt --name Kalman_s_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# dual_kalman: weights=['./weights_ex/smodel/best_s_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.024s)
# ...

# %%
# m
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/mmodel/best_m_5.pt --name Kalman_m_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# dual_kalman: weights=['./weights_ex/mmodel/best_m_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.034s)
# ...

# %%
# l
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/lmodel/best_l_5.pt --name Kalman_l_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# dual_kalman: weights=['./weights_ex/lmodel/best_l_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.042s)
# ...

# %%
# xl
# !python dual_kalman.py --source frame.mp4 --weight ./weights_ex/xlmodel/best_xl_5.pt --name Kalman_xl_result --save-conf  --save-txt --device 0,1,2,3  --conf-thres 0.35
# Out:
# dual_kalman: weights=['./weights_ex/xlmodel/best_xl_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=Kalman_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.054s)
# ...

# %% [markdown]
# # Gicheol_kalman

# %%
# n
# !python detect_Kalman_gicheol.py --source frame.mp4 --weight ./weights_ex/nmodel/best_n_5.pt --name gicheol_n_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_Kalman_gicheol: weights=['./weights_ex/nmodel/best_n_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=gicheol_n_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients, 4.2 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.031s)
# ...

# %%
# s
# !python detect_Kalman_gicheol.py --source frame.mp4 --weight ./weights_ex/smodel/best_s_5.pt --name gicheol_s_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_Kalman_gicheol: weights=['./weights_ex/smodel/best_s_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=gicheol_s_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.022s)
# ...

# %%
# m
# !python detect_Kalman_gicheol.py --source frame.mp4 --weight ./weights_ex/mmodel/best_m_5.pt --name gicheol_m_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_Kalman_gicheol: weights=['./weights_ex/mmodel/best_m_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=gicheol_m_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.032s)
# ...

# %%
# l
# !python detect_Kalman_gicheol.py --source frame.mp4 --weight ./weights_ex/lmodel/best_l_5.pt --name gicheol_l_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_Kalman_gicheol: weights=['./weights_ex/lmodel/best_l_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=gicheol_l_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.036s)
# ...

# %%
# xl
# !python detect_Kalman_gicheol.py --source frame.mp4 --weight ./weights_ex/xlmodel/best_xl_5.pt --name gicheol_xl_result --save-conf  --save-txt --device 0,1,2,3 --conf-thres 0.35
# Out:
# detect_Kalman_gicheol: weights=['./weights_ex/xlmodel/best_xl_5.pt'], source=frame.mp4, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=gicheol_xl_result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 42a5e0d6 torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                       CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
#                                       CUDA:3 (Tesla V100-DGXS-32GB, 32508MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/502) /workspace/Dual_kalman/yolo/frame.mp4: 384x640 1 drone, Done. (0.053s)
# ...
