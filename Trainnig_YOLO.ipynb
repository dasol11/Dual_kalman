# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla V100-DGXS-32GB'

# %%
torch.cuda.device_count()
# Out:
# 4

# %%
# %cd /workspace/yolo_kalman_v1/yolo
# Out:
# /workspace/yolo_kalman_v1/yolo

# %%
from glob import glob

img_list = glob('dataset/export/images/*.jpg')

print(len(img_list))
# Out:
# 6021

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size = 0.2, random_state = 2000)
print(len(train_img_list),len( val_img_list))
# Out:
# 4816 1205

# %%
with open('dataset/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open('dataset/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml


with open('dataset/data_drone.yaml', 'r') as f :
    data = yaml.load(f, Loader = yaml.FullLoader)
    
print(data)
data['train'] = 'dataset/train.txt'
data['val'] = 'dataset/val.txt'

with open ('dataset/data_drone.yaml','w') as f :
    yaml.dump(data, f)
print(data)
# Out:
# {'names': ['drone'], 'nc': 1, 'train': 'dataset/train.txt', 'val': 'dataset/val.txt'}
# {'names': ['drone'], 'nc': 1, 'train': 'dataset/train.txt', 'val': 'dataset/val.txt'}

# %% [markdown]
# # 학습처음시작할떄

# %%
# !python train.py --img 640 --batch 32 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5n.yaml --weight yolov5n.pt --name drone_n_result --worker 50  --device 0,1,2,3   --patience  100
# Out:
# train: weights=yolov5n.pt, cfg=./models/yolov5n.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1000, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=50, project=runs/train, name=drone_n_result, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 1de564b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5s.yaml --weight yolov5s.pt --name drone_s_result --worker 50 --device 0,1,2,3   --patience  100
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=50, project=runs/train, name=drone_s_result, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 1de564b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5m.yaml --weight yolov5m.pt --name drone_m_add --worker 50 --device 0,1,2,3   --patience  100
# Out:
# train: weights=yolov5m.pt, cfg=./models/yolov5m.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1000, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=50, project=runs/train, name=drone_m_add, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %%
# !python train.py --img 640 --batch 4 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5l.yaml --weight yolov5l.pt --name drone_l_add --worker 50 --device 0,1,2,3   --patience  200
# Out:
# train: weights=yolov5l.pt, cfg=./models/yolov5l.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1000, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=50, project=runs/train, name=drone_l_add, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=200, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %%
# !python train.py --img 640 --batch 4 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5x.yaml --weight yolov5x.pt --name drone_xl_add --worker 50 --device 0,1,2,3   --patience  200
# Out:
# train: weights=yolov5x.pt, cfg=./models/yolov5x.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1000, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=50, project=runs/train, name=drone_xl_add, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=200, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 1b55d2b torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                      CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                      CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %% [markdown]
# # 일단 여기까지

# %%
# !python train.py --img 640 --batch 32 --epochs 1000  --data ./dataset/data_drone.yaml --cfg ./models/yolov5n.yaml --weight yolov5n.pt --name drone_n_results --worker 20 --device 0,1,2,3
# Out:
# train: weights=yolov5n.pt, cfg=./models/yolov5n.yaml, data=./dataset/data_drone.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=20, project=runs/train, name=drone_n_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.2+cu113 CUDA:0 (Tesla V100-DGXS-32GB, 32500MiB)
#                                               CUDA:1 (Tesla V100-DGXS-32GB, 32508MiB)
#                                               CUDA:2 (Tesla V100-DGXS-32GB, 32508MiB)
# ...

# %% [markdown]
# # 중간에 끊어지는 경우

# %%
# !python train.py  --resume runs/train/drone_m_results3/weights/last.pt
