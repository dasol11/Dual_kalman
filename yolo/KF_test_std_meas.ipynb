# %%
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %cd C:\Users\qorwl\yolov5_py38\yolov5-master\runs\detect\
# Out:
# C:\Users\qorwl\yolov5_py38\yolov5-master\runs\detect

# %%
txt_list = glob('./test_pistol_yolov5/labels/*.txt') #Kalman
print(len(txt_list))
txt_list2 = glob('./test_pistol_Kalman6/labels/*.txt')#YOLO
print(len(txt_list2))
txt_list3 = glob('./test_pistol_Kalman7/labels/*.txt')
print(len(txt_list2))
# Out:
# 282
# 282
# 282

# %%
with open('./test_pistol_yolov5/test.txt', 'w') as f:
  f.write('\n'.join(txt_list) + '\n')

# %%
with open('./test_pistol_Kalman6/test2.txt', 'w') as f:
  f.write('\n'.join(txt_list2) + '\n')

# %%
with open('./test_pistol_Kalman7/test.txt', 'w') as f:
  f.write('\n'.join(txt_list3) + '\n')

# %%
filenames = []
f = open('./test_pistol_yolov5/test.txt', 'r')
while True:
    line = f.readline()
    line = line[0:-1]
    filenames.append((line))
    if not line: 
        print(len(filenames))
        break
    
f.close()
# Out:
# 283

# %%
filenames2 = []
f= open('./test_pistol_Kalman6/test2.txt', 'r')
while True:
    line2 = f.readline()
    line2 = line2[0:-1]
    filenames2.append((line2))
    if not line2: 
        print(len(filenames2))
        break
    
f.close()
# Out:
# 283

# %%
filenames3 = []
f= open('./test_pistol_Kalman7/test.txt', 'r')
while True:
    line3 = f.readline()
    line3 = line3[0:-1]
    filenames3.append((line3))
    if not line3: 
        print(len(filenames3))
        break
    
f.close()
# Out:
# 283

# %%
with open('./test_pistol_yolov5/merge.txt', 'w') as outfile:
    for filename in filenames:
        if filename == '':
            break
        with open(filename) as file:
            for line in file:
                outfile.write(line)

# %%
with open('./test_pistol_Kalman6/merge2.txt', 'w') as outfile:
    for filename2 in filenames2:
        if filename2 == '':
            break
        with open(filename2) as file:
            for line2 in file:
                outfile.write(line2)

# %%
with open('./test_pistol_Kalman7/merge2.txt', 'w') as outfile:
    for filename3 in filenames3:
        if filename3 == '':
            break
        with open(filename3) as file:
            for line3 in file:
                outfile.write(line3)

# %%
df = pd.read_csv(
    './test_pistol_yolov5/merge.txt', sep=" ",header=None)

df2 = pd.read_csv(
    './test_pistol_Kalman6/merge2.txt', sep=" ",header=None)

df3 = pd.read_csv(
    './test_pistol_Kalman7/merge2.txt', sep=" ",header=None)

# %%
df.rename(columns = {1 : 'Yolo_x', 2:'Yolo_y',3:'Yolo_w', 4: 'Yolo_h', 5:'Yolo_conf'}, inplace = True)
print(df2)
# Out:
#        0         1         2         3         4         5
# 0    0.5  0.000000  0.000000  0.000260  0.000463  0.500000
# 1    0.0  0.323958  0.205556  0.323958  0.515741  0.566838
# 2    0.0  0.480729  0.386111  0.288021  0.493519  0.448945
# 3    0.0  0.480729  0.387037  0.283854  0.489815  0.485347
# 4    0.0  0.480729  0.387963  0.283854  0.487037  0.488478
# ..   ...       ...       ...       ...       ...       ...
# 277  0.0  0.478125  0.384259  0.291146  0.493519  0.492944
# 278  0.0  0.478646  0.384259  0.280729  0.490741  0.282278
# 279  0.0  0.479167  0.384259  0.285417  0.496296  0.400258
# 280  0.0  0.479687  0.385185  0.271354  0.491667  0.295083
# 281  0.0  0.480208  0.386111  0.280208  0.489815  0.412891
#
# [282 rows x 6 columns]

# %%
df2.rename(columns = {1 : 'Kalman_x', 2:'Kalman_y',3:'Kalman_w', 4: 'Kalman_h', 5:'Kalman_conf'}, inplace = True)
print(df3)
# Out:
#        0         1         2         3         4         5
# 0    0.5  0.000000  0.000000  0.000260  0.000463  0.500000
# 1    0.0  0.360417  0.229630  0.323958  0.515741  0.566838
# 2    0.0  0.535417  0.414815  0.288021  0.493519  0.448945
# 3    0.0  0.533854  0.415741  0.283854  0.489815  0.485347
# 4    0.0  0.532292  0.416667  0.283854  0.487037  0.488478
# ..   ...       ...       ...       ...       ...       ...
# 277  0.0  0.542708  0.410185  0.291146  0.493519  0.492944
# 278  0.0  0.541146  0.411111  0.280729  0.490741  0.282278
# 279  0.0  0.539583  0.412037  0.285417  0.496296  0.400258
# 280  0.0  0.538021  0.412963  0.271354  0.491667  0.295083
# 281  0.0  0.536979  0.413889  0.280208  0.489815  0.412891
#
# [282 rows x 6 columns]

# %%
df3.rename(columns = {1 : 'Kalman_x', 2:'Kalman_y',3:'Kalman_w', 4: 'Kalman_h', 5:'Kalman_conf'}, inplace = True)
print(df3)
# Out:
#        0  Kalman_x  Kalman_y  Kalman_w  Kalman_h  Kalman_conf
# 0    0.5  0.000000  0.000000  0.000260  0.000463     0.500000
# 1    0.0  0.360417  0.229630  0.323958  0.515741     0.566838
# 2    0.0  0.535417  0.414815  0.288021  0.493519     0.448945
# 3    0.0  0.533854  0.415741  0.283854  0.489815     0.485347
# 4    0.0  0.532292  0.416667  0.283854  0.487037     0.488478
# ..   ...       ...       ...       ...       ...          ...
# 277  0.0  0.542708  0.410185  0.291146  0.493519     0.492944
# 278  0.0  0.541146  0.411111  0.280729  0.490741     0.282278
# 279  0.0  0.539583  0.412037  0.285417  0.496296     0.400258
# 280  0.0  0.538021  0.412963  0.271354  0.491667     0.295083
# 281  0.0  0.536979  0.413889  0.280208  0.489815     0.412891
#
# [282 rows x 6 columns]

# %%
# %cd C:\Users\qorwl\yolov5_py38\yolov5-master
# Out:
# C:\Users\qorwl\yolov5_py38\yolov5-master

# %%
plt.plot(df['Yolo_x'], label ='Yolo_x')
plt.plot(df2['Kalman_x'], label ='Kalman_x')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('x_Pos', labelpad=20)
plt.title('KalmanFilter((1 / dataset.frames), 1, 1, 1, 1, 1)')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/x_std_meas_1.png')
plt.show()

# %%
plt.plot(df['Yolo_x'], label ='Yolo_x')
plt.plot(df3['Kalman_x'], label ='Kalman_x')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('x_Pos', labelpad=20)
plt.title('KalmanFilter((1 / dataset.frames), 1, 1, 1, 0.01, 0.01)')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/x_std_meas_0.01.png')
plt.show()

# %%
plt.plot(df['Yolo_y'], label ='Yolo_y')
plt.plot(df2['Kalman_y'], label ='Kalman_y')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('y_Pos', labelpad=20)
plt.title('KalmanFilter((1 / dataset.frames), 1, 1, 1, 1, 1)')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/y_std_meas_1.png')
plt.show()

# %%
plt.plot(df['Yolo_y'], label ='Yolo_y')
plt.plot(df3['Kalman_y'], label ='Kalman_y')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('y_Pos', labelpad=20)
plt.title('KalmanFilter((1 / dataset.frames), 1, 1, 1, 0.01, 0.01)')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/y_std_meas_0.01.png')
plt.show()

# %%
plt.plot(df2['Kalman_y'], label ='y_std_meas_1')
plt.plot(df3['Kalman_y'], label ='y_std_meas_0.01')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('y_Pos', labelpad=20)
plt.title('y_std_meas_1 Vs y_std_meas_0.01')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/y_std_meas_VS.png')
plt.show()

# %%
plt.plot(df2['Kalman_x'], label ='x_std_meas_1')
plt.plot(df3['Kalman_x'], label ='x_std_meas_0.01')
plt.xlabel('Frame', labelpad=15)
plt.ylabel('x_Pos', labelpad=20)
plt.title('x_std_meas_1 Vs x_std_meas_0.01')
plt.ylim(0,0.7)
plt.legend(loc='upper right')
plt.savefig('./img/act/x_std_meas_VS.png')
plt.show()
